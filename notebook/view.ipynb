# %%
import pandas as pd

# %%
# %pwd
# Out:
# '/home/lyan/Project/BigData/Agent4DA/notebook'

# %%
# %ls ../data/
# Out:
# event_test_1000.csv

# %%
df = pd.read_csv("/home/lyan/Project/BigData/Agent4DA/data/event_test_1000.csv")

# %%
df
# Out:
#                   event_time event_type  product_id          category_id  \
# 0    2020-01-01 00:00:00 UTC       view     1005073  2232732093077520756
# 1    2020-01-01 00:00:01 UTC       view     1005192  2232732093077520756
# 2    2020-01-01 00:00:01 UTC       view   100063693  2053013552427434207
# 3    2020-01-01 00:00:01 UTC       view     5100816  2232732103831716449
# 4    2020-01-01 00:00:02 UTC       view   100014325  2232732103294845523
# ..                       ...        ...         ...                  ...
# 995  2020-01-01 00:05:32 UTC       view    27400032  2232732087742365937
# 996  2020-01-01 00:05:33 UTC       view     1005105  2232732093077520756
# 997  2020-01-01 00:05:34 UTC       view     1003936  2232732093077520756
# 998  2020-01-01 00:05:34 UTC       view     4804055  2232732079706079299
# 999  2020-01-01 00:05:34 UTC       view     6400313  2232732103294845523
#
#                 category_code    brand    price    user_id  \
# ...

# %%
df.columns
# Out:
# Index(['event_time', 'event_type', 'product_id', 'category_id',
#        'category_code', 'brand', 'price', 'user_id', 'user_session'],
#       dtype='str')
