# %%
import pandas as pd
import s3fs

# Define connection details
minio_endpoint = 'http://localhost:9000'
access_key = 'admin'
secret_key = 'Admin123!'

# Create the filesystem object
fs = s3fs.S3FileSystem(
    key=access_key,
    secret=secret_key,
    client_kwargs={'endpoint_url': minio_endpoint}
)

# %%
files = fs.glob("s3://bronze/ecommerce_events/**/*.parquet")

bronze_df = pd.read_parquet(
    files,
    filesystem=fs,
    engine="pyarrow"
)

bronze_df.head()
# Out:
#                 event_time event_type product_id          category_id  \
# 0  2020-01-01 00:00:00 UTC       view    1005073  2232732093077520756
# 1  2020-01-01 00:00:02 UTC       view  100014325  2232732103294845523
# 2  2020-01-01 00:00:02 UTC       view   11600004  2053013554834964853
# 3  2020-01-01 00:00:03 UTC       view    3100055  2232732091391410500
# 4  2020-01-01 00:00:04 UTC       view   16500038  2232732108713886406
#
#                 category_code    brand    price    user_id  \
# 0    construction.tools.light  samsung  1130.02  519698804
# 1      apparel.shoes.step_ins    intel   167.20  587748686
# 2   appliances.kitchen.kettle     sven    43.48  595265136
# 3  appliances.kitchen.blender    braun   117.09  558295901
# 4             apparel.costume    bwell    56.63  526238299
#
#                            user_session                kafka_ts  \
# 0  69b5d72f-fd6e-4fed-aa23-1286b2ca89a0 2026-05-18 05:18:02.315
# 1  31b7d4cf-dfac-4895-9927-90fa3254f860 2026-05-18 05:18:02.315
# 2  32c08a07-f2d0-4da5-83fd-40ce97c651e6 2026-05-18 05:18:02.315
# 3  e7934107-4212-4b1b-a8e1-6dbec9b4daf5 2026-05-18 05:18:02.315
# 4  7f47e97f-3833-47b0-95a6-b8b61ff73fef 2026-05-18 05:18:02.316
#
#    kafka_partition  kafka_offset                ingested_at date_partition
# 0                0          1979 2026-05-18 16:24:58.429265     2026-05-18
# 1                0          1980 2026-05-18 16:24:58.429265     2026-05-18
# 2                0          1981 2026-05-18 16:24:58.429265     2026-05-18
# 3                0          1982 2026-05-18 16:24:58.429265     2026-05-18
# 4                0          1983 2026-05-18 16:24:58.429265     2026-05-18
